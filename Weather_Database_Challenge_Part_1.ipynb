# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#use the citipy module to determine city based on latitude and longitude
from citipy import citipy
#import the datetime module from the datetime library
from datetime import datetime
#for API requests
import requests
#import the API key
from config import weather_api_key
# Import the time module.
import time
# Import linear regression from the SciPy stats module
from scipy.stats import linregress

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities
cities = []
#identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key

# %%
#create an empty list to hold the weather data
city_data = []
#print the start of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#initializee counters
record_count = 1
set_count = 1

#loop through all the cities in the list
for i, city in enumerate(cities):

    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create endpoint URL with each city
    city_url = url + "&q=" + city

    #log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to the record count
    record_count += 1
    
    #run an API request for each of the cities
    try:
        #parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        try:
            city_rain_3h = city_weather["rain"]["3h"]
            city_snow_3h = city_weather["snow"]["3h"]
        except:
            city_rain_3h=0
            city_snow_3h=0
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current description": city_desc,
                          "Rain (last 3 hrs)": city_rain_3h,
                          "Snow (last 3 hrs)": city_snow_3h,
                          "Date": city_date})

#if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | port moresby
# Processing Record 3 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 1 | moyale
# Processing Record 7 of Set 1 | broken hill
# Processing Record 8 of Set 1 | rantepao
# Processing Record 9 of Set 1 | hofn
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | san quintin
# Processing Record 13 of Set 1 | silyanah
# City not found. Skipping...
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | shalu
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | ekhabi
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | sulangan
# Processing Record 32 of Set 1 | fairbanks
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | zhigansk
# Processing Record 36 of Set 1 | mackenzie
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | kaka
# Processing Record 39 of Set 1 | quimper
# Processing Record 40 of Set 1 | kjollefjord
# Processing Record 41 of Set 1 | surt
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | santa fe
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | mulege
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | manado
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | lufilufi
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 2 | itatuba
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | nongstoin
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | najran
# Processing Record 17 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | abu dhabi
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | katangli
# Processing Record 28 of Set 2 | pishin
# Processing Record 29 of Set 2 | dingle
# Processing Record 30 of Set 2 | mecca
# Processing Record 31 of Set 2 | aktash
# Processing Record 32 of Set 2 | gamba
# Processing Record 33 of Set 2 | placido de castro
# Processing Record 34 of Set 2 | pizhanka
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | campoverde
# Processing Record 40 of Set 2 | powell
# Processing Record 41 of Set 2 | shingu
# Processing Record 42 of Set 2 | mindelo
# Processing Record 43 of Set 2 | eureka
# Processing Record 44 of Set 2 | richards bay
# Processing Record 45 of Set 2 | sao felix do xingu
# Processing Record 46 of Set 2 | bandundu
# Processing Record 47 of Set 2 | tilichiki
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | saint-augustin
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | povenets
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | magadan
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | zyryanka
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | mankono
# Processing Record 14 of Set 3 | marawi
# Processing Record 15 of Set 3 | ninotsminda
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | benguela
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | new richmond
# Processing Record 20 of Set 3 | raybag
# Processing Record 21 of Set 3 | kyshtovka
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | avera
# Processing Record 26 of Set 3 | wanaka
# Processing Record 27 of Set 3 | muisne
# Processing Record 28 of Set 3 | san marcos
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | agirish
# Processing Record 31 of Set 3 | kedrovyy
# Processing Record 32 of Set 3 | vigrestad
# Processing Record 33 of Set 3 | moron
# Processing Record 34 of Set 3 | progreso
# Processing Record 35 of Set 3 | poum
# Processing Record 36 of Set 3 | havelock
# Processing Record 37 of Set 3 | manavalakurichi
# Processing Record 38 of Set 3 | puerto el triunfo
# Processing Record 39 of Set 3 | kununurra
# Processing Record 40 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 3 | porkhov
# Processing Record 42 of Set 3 | laguna
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | leningradskiy
# Processing Record 45 of Set 3 | fortuna
# Processing Record 46 of Set 3 | mayo
# Processing Record 47 of Set 3 | riosucio
# Processing Record 48 of Set 3 | naze
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | beringovskiy
# Processing Record 1 of Set 4 | lasa
# Processing Record 2 of Set 4 | noumea
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | hovd
# Processing Record 5 of Set 4 | vallenar
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | taltal
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | impfondo
# Processing Record 10 of Set 4 | kuytun
# Processing Record 11 of Set 4 | charters towers
# Processing Record 12 of Set 4 | grand gaube
# Processing Record 13 of Set 4 | porto novo
# Processing Record 14 of Set 4 | hami
# Processing Record 15 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 4 | hearst
# Processing Record 17 of Set 4 | dakar
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | qandala
# Processing Record 24 of Set 4 | valdivia
# Processing Record 25 of Set 4 | vao
# Processing Record 26 of Set 4 | beyneu
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | abalak
# Processing Record 29 of Set 4 | akureyri
# Processing Record 30 of Set 4 | coihaique
# Processing Record 31 of Set 4 | deniliquin
# Processing Record 32 of Set 4 | pierre
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | ribas do rio pardo
# Processing Record 35 of Set 4 | evensk
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | rawson
# Processing Record 38 of Set 4 | rocha
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | wladyslawowo
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | aswan
# Processing Record 43 of Set 4 | cockburn town
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | salekhard
# Processing Record 47 of Set 4 | chiang klang
# Processing Record 48 of Set 4 | chandla
# Processing Record 49 of Set 4 | guerrero negro
# Processing Record 50 of Set 4 | sola
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | kuusamo
# Processing Record 4 of Set 5 | kindu
# Processing Record 5 of Set 5 | lebu
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | srednekolymsk
# Processing Record 8 of Set 5 | toamasina
# Processing Record 9 of Set 5 | kapaa
# Processing Record 10 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | matagami
# Processing Record 13 of Set 5 | aksum
# Processing Record 14 of Set 5 | lundazi
# Processing Record 15 of Set 5 | chicama
# Processing Record 16 of Set 5 | kidal
# Processing Record 17 of Set 5 | bjornevatn
# Processing Record 18 of Set 5 | vestmanna
# Processing Record 19 of Set 5 | maningrida
# Processing Record 20 of Set 5 | maceio
# Processing Record 21 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | chikoy
# City not found. Skipping...
# Processing Record 25 of Set 5 | lichtenburg
# Processing Record 26 of Set 5 | longyearbyen
# Processing Record 27 of Set 5 | beisfjord
# Processing Record 28 of Set 5 | zhangye
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | simga
# Processing Record 32 of Set 5 | kargat
# Processing Record 33 of Set 5 | harboore
# Processing Record 34 of Set 5 | mangrol
# Processing Record 35 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | albox
# Processing Record 40 of Set 5 | mikhaylovka
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | manta
# Processing Record 43 of Set 5 | constitucion
# Processing Record 44 of Set 5 | pevek
# Processing Record 45 of Set 5 | gillette
# Processing Record 46 of Set 5 | kailua
# Processing Record 47 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 5 | butaritari
# Processing Record 49 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 5 | kuala terengganu
# Processing Record 1 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 2 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | tha mai
# Processing Record 5 of Set 6 | palembang
# Processing Record 6 of Set 6 | bumba
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | rundu
# Processing Record 9 of Set 6 | mar del plata
# Processing Record 10 of Set 6 | ludza
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | santa vitoria do palmar
# Processing Record 13 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 6 | waipawa
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | sistranda
# Processing Record 17 of Set 6 | awjilah
# Processing Record 18 of Set 6 | kawalu
# Processing Record 19 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 6 | san francisco
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | wiarton
# Processing Record 23 of Set 6 | saint-pierre
# Processing Record 24 of Set 6 | hede
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | chernyshevskiy
# Processing Record 27 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 6 | saryg-sep
# Processing Record 29 of Set 6 | acapulco
# Processing Record 30 of Set 6 | saint-ambroise
# Processing Record 31 of Set 6 | ust-kuyga
# Processing Record 32 of Set 6 | clovis
# Processing Record 33 of Set 6 | oranjemund
# Processing Record 34 of Set 6 | kungurtug
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | tula
# Processing Record 37 of Set 6 | dodge city
# Processing Record 38 of Set 6 | jizan
# Processing Record 39 of Set 6 | kijang
# Processing Record 40 of Set 6 | isangel
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | gigmoto
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | warren
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | dubbo
# Processing Record 47 of Set 6 | mazagao
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | gravdal
# Processing Record 2 of Set 7 | tuatapere
# Processing Record 3 of Set 7 | sangueya
# Processing Record 4 of Set 7 | san ramon
# Processing Record 5 of Set 7 | dyersburg
# Processing Record 6 of Set 7 | batsfjord
# Processing Record 7 of Set 7 | hualmay
# Processing Record 8 of Set 7 | fuyu
# Processing Record 9 of Set 7 | deputatskiy
# Processing Record 10 of Set 7 | ust-charyshskaya pristan
# Processing Record 11 of Set 7 | lugovskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | ibipeba
# Processing Record 14 of Set 7 | zhuozhou
# City not found. Skipping...
# Processing Record 15 of Set 7 | vardo
# Processing Record 16 of Set 7 | mogadishu
# Processing Record 17 of Set 7 | islamkot
# Processing Record 18 of Set 7 | vostok
# Processing Record 19 of Set 7 | yuli
# Processing Record 20 of Set 7 | ponta pora
# Processing Record 21 of Set 7 | haines junction
# Processing Record 22 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 7 | taseyevo
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | jinchang
# Processing Record 26 of Set 7 | cabo san lucas
# Processing Record 27 of Set 7 | isla mujeres
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | lokoja
# Processing Record 30 of Set 7 | kulhudhuffushi
# Processing Record 31 of Set 7 | usvyaty
# Processing Record 32 of Set 7 | sazonovo
# Processing Record 33 of Set 7 | portel
# Processing Record 34 of Set 7 | ribeira grande
# Processing Record 35 of Set 7 | jacksonville
# Processing Record 36 of Set 7 | wanning
# Processing Record 37 of Set 7 | csanadpalota
# Processing Record 38 of Set 7 | manadhoo
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | strezhevoy
# Processing Record 41 of Set 7 | dharchula
# Processing Record 42 of Set 7 | roald
# Processing Record 43 of Set 7 | shache
# Processing Record 44 of Set 7 | kutum
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | sambava
# Processing Record 47 of Set 7 | japura
# Processing Record 48 of Set 7 | myrtle beach
# Processing Record 49 of Set 7 | loubomo
# Processing Record 50 of Set 7 | tigil
# Processing Record 1 of Set 8 | bathsheba
# Processing Record 2 of Set 8 | lavrentiya
# Processing Record 3 of Set 8 | dicabisagan
# Processing Record 4 of Set 8 | balyaga
# Processing Record 5 of Set 8 | nabinagar
# Processing Record 6 of Set 8 | bandarbeyla
# Processing Record 7 of Set 8 | alofi
# Processing Record 8 of Set 8 | fort nelson
# Processing Record 9 of Set 8 | el alto
# Processing Record 10 of Set 8 | inhambane
# Processing Record 11 of Set 8 | chara
# Processing Record 12 of Set 8 | quatre cocos
# Processing Record 13 of Set 8 | qibili
# City not found. Skipping...
# Processing Record 14 of Set 8 | antofagasta
# Processing Record 15 of Set 8 | whitehorse
# Processing Record 16 of Set 8 | kiunga
# Processing Record 17 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 18 of Set 8 | flinders
# Processing Record 19 of Set 8 | taoudenni
# Processing Record 20 of Set 8 | clifton
# Processing Record 21 of Set 8 | jijiga
# Processing Record 22 of Set 8 | bonavista
# Processing Record 23 of Set 8 | abu samrah
# Processing Record 24 of Set 8 | taikang
# Processing Record 25 of Set 8 | bakani
# Processing Record 26 of Set 8 | moindou
# Processing Record 27 of Set 8 | russell
# Processing Record 28 of Set 8 | sukumo
# Processing Record 29 of Set 8 | kysyl-syr
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | kasongo-lunda
# Processing Record 32 of Set 8 | akdepe
# Processing Record 33 of Set 8 | bantogon
# Processing Record 34 of Set 8 | gorom-gorom
# Processing Record 35 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 8 | tucuman
# Processing Record 37 of Set 8 | kushmurun
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | stara zagora
# Processing Record 40 of Set 8 | ejutla de crespo
# Processing Record 41 of Set 8 | bousso
# Processing Record 42 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 43 of Set 8 | port shepstone
# Processing Record 44 of Set 8 | okhotsk
# Processing Record 45 of Set 8 | pacific grove
# Processing Record 46 of Set 8 | hokitika
# Processing Record 47 of Set 8 | shihezi
# Processing Record 48 of Set 8 | nerchinskiy zavod
# Processing Record 49 of Set 8 | tonantins
# Processing Record 50 of Set 8 | pelagiada
# Processing Record 1 of Set 9 | roma
# Processing Record 2 of Set 9 | buala
# Processing Record 3 of Set 9 | amapa
# Processing Record 4 of Set 9 | oistins
# Processing Record 5 of Set 9 | mayskiy
# Processing Record 6 of Set 9 | iqaluit
# Processing Record 7 of Set 9 | great yarmouth
# Processing Record 8 of Set 9 | luena
# Processing Record 9 of Set 9 | kalabo
# Processing Record 10 of Set 9 | morgan city
# Processing Record 11 of Set 9 | karakol
# Processing Record 12 of Set 9 | leshukonskoye
# Processing Record 13 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 9 | tiruppur
# Processing Record 15 of Set 9 | reidsville
# Processing Record 16 of Set 9 | mokhotlong
# Processing Record 17 of Set 9 | xapuri
# Processing Record 18 of Set 9 | boende
# Processing Record 19 of Set 9 | binzhou
# Processing Record 20 of Set 9 | saint-joseph
# Processing Record 21 of Set 9 | waspan
# Processing Record 22 of Set 9 | singleton
# Processing Record 23 of Set 9 | jaumave
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | puerto leguizamo
# Processing Record 26 of Set 9 | port hardy
# Processing Record 27 of Set 9 | brae
# Processing Record 28 of Set 9 | karratha
# Processing Record 29 of Set 9 | sal rei
# Processing Record 30 of Set 9 | aklavik
# Processing Record 31 of Set 9 | itaituba
# Processing Record 32 of Set 9 | alice town
# Processing Record 33 of Set 9 | ndjole
# Processing Record 34 of Set 9 | atar
# Processing Record 35 of Set 9 | caramay
# Processing Record 36 of Set 9 | bulungu
# Processing Record 37 of Set 9 | ko samui
# Processing Record 38 of Set 9 | sao joao da barra
# Processing Record 39 of Set 9 | duldurga
# Processing Record 40 of Set 9 | namatanai
# Processing Record 41 of Set 9 | abnub
# Processing Record 42 of Set 9 | chaman
# Processing Record 43 of Set 9 | port macquarie
# Processing Record 44 of Set 9 | wattegama
# Processing Record 45 of Set 9 | seredeyskiy
# Processing Record 46 of Set 9 | lesnoy
# Processing Record 47 of Set 9 | rock sound
# Processing Record 48 of Set 9 | vilhena
# Processing Record 49 of Set 9 | gazojak
# Processing Record 50 of Set 9 | diffa
# Processing Record 1 of Set 10 | vanimo
# Processing Record 2 of Set 10 | nehe
# Processing Record 3 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 10 | hadejia
# Processing Record 5 of Set 10 | tecoanapa
# Processing Record 6 of Set 10 | imbituba
# Processing Record 7 of Set 10 | camopi
# Processing Record 8 of Set 10 | dongsheng
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | qingdao
# Processing Record 11 of Set 10 | cedar city
# Processing Record 12 of Set 10 | the pas
# Processing Record 13 of Set 10 | newcastleton
# Processing Record 14 of Set 10 | prince rupert
# Processing Record 15 of Set 10 | tymovskoye
# Processing Record 16 of Set 10 | kamaishi
# Processing Record 17 of Set 10 | shizunai
# Processing Record 18 of Set 10 | viedma
# Processing Record 19 of Set 10 | nantucket
# Processing Record 20 of Set 10 | rawicz
# Processing Record 21 of Set 10 | haputale
# Processing Record 22 of Set 10 | arlit
# Processing Record 23 of Set 10 | baijiantan
# Processing Record 24 of Set 10 | lengshuijiang
# Processing Record 25 of Set 10 | talavera de la reina
# Processing Record 26 of Set 10 | shahreza
# Processing Record 27 of Set 10 | elizabeth city
# Processing Record 28 of Set 10 | abancay
# Processing Record 29 of Set 10 | novoagansk
# Processing Record 30 of Set 10 | guanica
# Processing Record 31 of Set 10 | grindavik
# Processing Record 32 of Set 10 | santa
# Processing Record 33 of Set 10 | khanu woralaksaburi
# Processing Record 34 of Set 10 | mapimi
# Processing Record 35 of Set 10 | fuling
# Processing Record 36 of Set 10 | batagay-alyta
# Processing Record 37 of Set 10 | dzhebariki-khaya
# Processing Record 38 of Set 10 | rio grande
# Processing Record 39 of Set 10 | kalmunai
# Processing Record 40 of Set 10 | guanhaes
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | genhe
# Processing Record 43 of Set 10 | port keats
# Processing Record 44 of Set 10 | el fuerte
# Processing Record 45 of Set 10 | mount isa
# Processing Record 46 of Set 10 | olhao
# Processing Record 47 of Set 10 | coquimbo
# Processing Record 48 of Set 10 | ust-nera
# Processing Record 49 of Set 10 | camacha
# Processing Record 50 of Set 10 | veraval
# Processing Record 1 of Set 11 | bud
# Processing Record 2 of Set 11 | songea
# Processing Record 3 of Set 11 | klyuchi
# Processing Record 4 of Set 11 | vrangel
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | bria
# Processing Record 7 of Set 11 | huarmey
# Processing Record 8 of Set 11 | honiara
# Processing Record 9 of Set 11 | bage
# Processing Record 10 of Set 11 | shenzhen
# Processing Record 11 of Set 11 | yulara
# Processing Record 12 of Set 11 | baruun-urt
# Processing Record 13 of Set 11 | rio cuarto
# Processing Record 14 of Set 11 | morondava
# Processing Record 15 of Set 11 | solnechnyy
# Processing Record 16 of Set 11 | sakakah
# Processing Record 17 of Set 11 | siniscola
# Processing Record 18 of Set 11 | port hedland
# Processing Record 19 of Set 11 | emerald
# Processing Record 20 of Set 11 | denpasar
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | nome
# Processing Record 23 of Set 11 | omboue
# Processing Record 24 of Set 11 | kolondieba
# Processing Record 25 of Set 11 | shahrud
# Processing Record 26 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 11 | sodertalje
# City not found. Skipping...
# Processing Record 28 of Set 11 | santa maria
# Processing Record 29 of Set 11 | alma
# Processing Record 30 of Set 11 | markova
# Processing Record 31 of Set 11 | riyadh
# Processing Record 32 of Set 11 | kaeo
# Processing Record 33 of Set 11 | cacequi
# Processing Record 34 of Set 11 | porto walter
# Processing Record 35 of Set 11 | marrakesh
# Processing Record 36 of Set 11 | okato
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | osakarovka
# Processing Record 39 of Set 11 | huilong
# Processing Record 40 of Set 11 | makakilo city
# Processing Record 41 of Set 11 | pringsewu
# Processing Record 42 of Set 11 | presidencia roque saenz pena
# Processing Record 43 of Set 11 | san jeronimo
# Processing Record 44 of Set 11 | pec
# Processing Record 45 of Set 11 | dzilam gonzalez
# Processing Record 46 of Set 11 | tateyama
# Processing Record 47 of Set 11 | ambilobe
# Processing Record 48 of Set 11 | quesnel
# Processing Record 49 of Set 11 | raga
# Processing Record 50 of Set 11 | ladario
# Processing Record 1 of Set 12 | guasdualito
# Processing Record 2 of Set 12 | tamandare
# Processing Record 3 of Set 12 | ganzhou
# Processing Record 4 of Set 12 | ketchikan
# Processing Record 5 of Set 12 | barra do garcas
# Processing Record 6 of Set 12 | freetown
# Processing Record 7 of Set 12 | hobyo
# Processing Record 8 of Set 12 | lewisburg
# Processing Record 9 of Set 12 | monywa
# Processing Record 10 of Set 12 | jinka
# Processing Record 11 of Set 12 | woodstock
# Processing Record 12 of Set 12 | thunder bay
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 | monticello
# Processing Record 15 of Set 12 | eyl
# Processing Record 16 of Set 12 | saint george
# Processing Record 17 of Set 12 | scarborough
# Processing Record 18 of Set 12 | berdigestyakh
# Processing Record 19 of Set 12 | lloro
# Processing Record 20 of Set 12 | tabas
# Processing Record 21 of Set 12 | umm kaddadah
# Processing Record 22 of Set 12 | pitimbu
# Processing Record 23 of Set 12 | gornoye loo
# Processing Record 24 of Set 12 | wenling
# Processing Record 25 of Set 12 | pisco
# Processing Record 26 of Set 12 | ler
# Processing Record 27 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 12 | kombissiri
# Processing Record 29 of Set 12 | juba
# Processing Record 30 of Set 12 | skibbereen
# Processing Record 31 of Set 12 | rochester
# Processing Record 32 of Set 12 | nemuro
# Processing Record 33 of Set 12 | hastings
# Processing Record 34 of Set 12 | puerto del rosario
# Processing Record 35 of Set 12 | tagusao
# Processing Record 36 of Set 12 | kuybysheve
# Processing Record 37 of Set 12 | havre-saint-pierre
# Processing Record 38 of Set 12 | yerbogachen
# Processing Record 39 of Set 12 | cheshire
# Processing Record 40 of Set 12 | kondopoga
# Processing Record 41 of Set 12 | chabahar
# Processing Record 42 of Set 12 | kosh
# Processing Record 43 of Set 12 | salinas
# Processing Record 44 of Set 12 | manama
# Processing Record 45 of Set 12 | atherton
# Processing Record 46 of Set 12 | tambo
# Processing Record 47 of Set 12 | kenai
# Processing Record 48 of Set 12 | rennes
# Processing Record 49 of Set 12 | antigonish
# Processing Record 50 of Set 12 | phanat nikhom
# Processing Record 1 of Set 13 | chute-aux-outardes
# Processing Record 2 of Set 13 | vestmannaeyjar
# Processing Record 3 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 4 of Set 13 | portage
# Processing Record 5 of Set 13 | khorixas
# Processing Record 6 of Set 13 | flin flon
# Processing Record 7 of Set 13 | westport
# Processing Record 8 of Set 13 | necochea
# Processing Record 9 of Set 13 | nanortalik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
city_weather
# Out:
# {'coord': {'lon': -45.24, 'lat': 60.14},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 30.18,
#   'feels_like': 17.08,
#   'temp_min': 30.18,
#   'temp_max': 30.18,
#   'pressure': 1015,
#   'humidity': 89,
#   'sea_level': 1015,
#   'grnd_level': 1014},
#  'wind': {'speed': 15.79, 'deg': 306},
#  'clouds': {'all': 14},
#  'dt': 1587322961,
#  'sys': {'country': 'GL', 'sunrise': 1587281424, 'sunset': 1587335349},
#  'timezone': -7200,
#  'id': 3421765,
#  'name': 'Nanortalik',
#  'cod': 200}

# %%
#convert the array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Port Moresby  -9.44  147.18     78.35        83          51        5.59
# 1          Hobart -42.88  147.33     51.80        76         100        5.82
# 2          Moyale   3.52   39.06     68.58        68         100        3.78
# 3     Broken Hill -31.95  141.43     69.80        28          75       18.34
# 4        Rantepao  -2.97  119.90     66.38        73          89        2.19
# ..            ...    ...     ...       ...       ...         ...         ...
# 559      Khorixas -20.37   14.97     81.68        30          62       16.62
# 560     Flin Flon  54.77 -101.86     37.40        69          75       14.99
# 561      Westport  41.14  -73.36     60.01        44           1       18.34
# 562      Necochea -38.55  -58.74     71.01        62          34        5.99
# 563    Nanortalik  60.14  -45.24     30.18        89          14       15.79
#
#     Country Current description  Rain (last 3 hrs)  Snow (last 3 hrs)  \
# 0        PG       broken clouds                  0                  0
# 1        AU     overcast clouds                  0                  0
# 2        KE          light rain                  0                  0
# 3        AU       broken clouds                  0                  0
# 4        ID          light rain                  0                  0
# ..      ...                 ...                ...                ...
# 559      NA          light rain                  0                  0
# 560      CA       broken clouds                  0                  0
# 561      US           clear sky                  0                  0
# 562      AR    scattered clouds                  0                  0
# 563      GL          few clouds                  0                  0
#
#                     Date
# 0    2020-04-19 19:03:54
# 1    2020-04-19 18:58:22
# 2    2020-04-19 19:03:56
# 3    2020-04-19 19:03:57
# 4    2020-04-19 19:03:57
# ..                   ...
# 559  2020-04-19 19:09:39
# 560  2020-04-19 19:09:39
# 561  2020-04-19 19:09:40
# 562  2020-04-19 19:06:36
# 563  2020-04-19 19:02:41
#
# [564 rows x 12 columns]

# %%
#,#"Rain (last 3hrs)",#"Snow (last 3hrs)"
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current description","Rain (last 3 hrs)","Snow (last 3 hrs)"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0    Port Moresby      PG  2020-04-19 19:03:54  -9.44  147.18     78.35
# 1          Hobart      AU  2020-04-19 18:58:22 -42.88  147.33     51.80
# 2          Moyale      KE  2020-04-19 19:03:56   3.52   39.06     68.58
# 3     Broken Hill      AU  2020-04-19 19:03:57 -31.95  141.43     69.80
# 4        Rantepao      ID  2020-04-19 19:03:57  -2.97  119.90     66.38
# ..            ...     ...                  ...    ...     ...       ...
# 559      Khorixas      NA  2020-04-19 19:09:39 -20.37   14.97     81.68
# 560     Flin Flon      CA  2020-04-19 19:09:39  54.77 -101.86     37.40
# 561      Westport      US  2020-04-19 19:09:40  41.14  -73.36     60.01
# 562      Necochea      AR  2020-04-19 19:06:36 -38.55  -58.74     71.01
# 563    Nanortalik      GL  2020-04-19 19:02:41  60.14  -45.24     30.18
#
#      Humidity  Cloudiness  Wind Speed Current description  Rain (last 3 hrs)  \
# 0          83          51        5.59       broken clouds                  0
# 1          76         100        5.82     overcast clouds                  0
# 2          68         100        3.78          light rain                  0
# 3          28          75       18.34       broken clouds                  0
# 4          73          89        2.19          light rain                  0
# ..        ...         ...         ...                 ...                ...
# 559        30          62       16.62          light rain                  0
# 560        69          75       14.99       broken clouds                  0
# 561        44           1       18.34           clear sky                  0
# 562        62          34        5.99    scattered clouds                  0
# 563        89          14       15.79          few clouds                  0
#
#      Snow (last 3 hrs)
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 559                  0
# 560                  0
# 561                  0
# 562                  0
# 563                  0
#
# [564 rows x 12 columns]

# %%
#create the output file (CSV)
output_data_file = "data/WeatherPy_challenge.csv"
#export the challenge weather data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
