# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#use the citipy module to determine city based on latitude and longitude
from citipy import citipy
#import the datetime module from the datetime library
from datetime import datetime
#for API requests
import requests
#import the API key
from config import weather_api_key
# Import the time module.
import time
# Import linear regression from the SciPy stats module
from scipy.stats import linregress

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities
cities = []
#identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key

# %%
#create an empty list to hold the weather data
city_data = []
#print the start of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#initializee counters
record_count = 1
set_count = 1

#loop through all the cities in the list
for i, city in enumerate(cities):

    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create endpoint URL with each city
    city_url = url + "&q=" + city

    #log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to the record count
    record_count += 1
    
    #run an API request for each of the cities
    try:
        #parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        try:
            city_rain_3h = city_weather["rain"]["3h"]
            city_snow_3h = city_weather["snow"]["3h"]
        except:
            city_rain_3h=0
            city_snow_3h=0
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current description": city_desc,
                          "Rain (last 3 hrs)": city_rain_3h,
                          "Snow (last 3 hrs)": city_snow_3h,
                          "Date": city_date})

#if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | vardo
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | markova
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | salina
# Processing Record 15 of Set 1 | affery
# Processing Record 16 of Set 1 | bilma
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | buala
# Processing Record 19 of Set 1 | camacha
# Processing Record 20 of Set 1 | nome
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | waitati
# Processing Record 26 of Set 1 | arinos
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | noumea
# Processing Record 34 of Set 1 | tuatapere
# Processing Record 35 of Set 1 | nouadhibou
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | padang
# Processing Record 39 of Set 1 | split
# Processing Record 40 of Set 1 | jiaocheng
# Processing Record 41 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 1 | mezen
# Processing Record 43 of Set 1 | avera
# Processing Record 44 of Set 1 | kavieng
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | jawa
# Processing Record 48 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | margate
# Processing Record 1 of Set 2 | kendari
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | bogatyye saby
# Processing Record 4 of Set 2 | mogadishu
# Processing Record 5 of Set 2 | chota
# Processing Record 6 of Set 2 | san juan
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | livenka
# Processing Record 12 of Set 2 | longkou
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | dingle
# Processing Record 15 of Set 2 | saint-augustin
# Processing Record 16 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 17 of Set 2 | jiangyou
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | osinniki
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | minggang
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | elhovo
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | jomalig
# City not found. Skipping...
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | dunedin
# Processing Record 34 of Set 2 | gizo
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | pandan
# Processing Record 38 of Set 2 | ugoofaaru
# Processing Record 39 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 2 | tsiroanomandidy
# Processing Record 41 of Set 2 | pisco
# Processing Record 42 of Set 2 | bonthe
# Processing Record 43 of Set 2 | high level
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | pedernales
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 2 | roma
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | nechi
# Processing Record 2 of Set 3 | sur
# Processing Record 3 of Set 3 | kyren
# Processing Record 4 of Set 3 | honningsvag
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | andenes
# Processing Record 9 of Set 3 | puerto del rosario
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | hukuntsi
# Processing Record 13 of Set 3 | meulaboh
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | nizwa
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | itambe
# Processing Record 19 of Set 3 | ushibuka
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | muzhi
# Processing Record 23 of Set 3 | dajal
# Processing Record 24 of Set 3 | tomatlan
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | rock sound
# Processing Record 27 of Set 3 | kloulklubed
# Processing Record 28 of Set 3 | egvekinot
# Processing Record 29 of Set 3 | stepnogorsk
# Processing Record 30 of Set 3 | little current
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | fandriana
# Processing Record 33 of Set 3 | constitucion
# Processing Record 34 of Set 3 | alquizar
# Processing Record 35 of Set 3 | westport
# Processing Record 36 of Set 3 | yigou
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | chapada dos guimaraes
# Processing Record 39 of Set 3 | richards bay
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | boa vista
# Processing Record 42 of Set 3 | sungairaya
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | kadan
# Processing Record 45 of Set 3 | bairiki
# Processing Record 46 of Set 3 | kitgum
# Processing Record 47 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 3 | tecoanapa
# Processing Record 49 of Set 3 | kabwe
# Processing Record 50 of Set 3 | khani
# Processing Record 1 of Set 4 | korla
# Processing Record 2 of Set 4 | mata
# Processing Record 3 of Set 4 | carutapera
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | havoysund
# Processing Record 7 of Set 4 | myaundzha
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | sitka
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | escanaba
# Processing Record 15 of Set 4 | bandar-e lengeh
# Processing Record 16 of Set 4 | marzuq
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | rochester
# Processing Record 19 of Set 4 | lagos
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | praia
# Processing Record 22 of Set 4 | caravelas
# Processing Record 23 of Set 4 | venado tuerto
# Processing Record 24 of Set 4 | mae hong son
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | faya
# Processing Record 27 of Set 4 | saint-michel-des-saints
# Processing Record 28 of Set 4 | mayo
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | lubango
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 4 | pemba
# Processing Record 34 of Set 4 | labrea
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | gat
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | vanimo
# Processing Record 39 of Set 4 | luanda
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | palu
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | occhiobello
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | vaini
# Processing Record 46 of Set 4 | robinson
# Processing Record 47 of Set 4 | port lincoln
# Processing Record 48 of Set 4 | the valley
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | bridlington
# Processing Record 1 of Set 5 | tabou
# Processing Record 2 of Set 5 | dali
# Processing Record 3 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | sechura
# Processing Record 6 of Set 5 | dubovyy umet
# Processing Record 7 of Set 5 | vestmanna
# Processing Record 8 of Set 5 | jalu
# Processing Record 9 of Set 5 | iskele
# City not found. Skipping...
# Processing Record 10 of Set 5 | yashan
# Processing Record 11 of Set 5 | sinnamary
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | iskateley
# Processing Record 15 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 5 | medford
# Processing Record 17 of Set 5 | pokhara
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 5 | waddan
# Processing Record 21 of Set 5 | barcelona
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | usakos
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | chicama
# Processing Record 26 of Set 5 | bokoro
# Processing Record 27 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 29 of Set 5 | namatanai
# Processing Record 30 of Set 5 | hit
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | kruisfontein
# Processing Record 34 of Set 5 | puerto madero
# Processing Record 35 of Set 5 | hongan
# City not found. Skipping...
# Processing Record 36 of Set 5 | havre-saint-pierre
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | along
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | atuona
# Processing Record 42 of Set 5 | mirnyy
# Processing Record 43 of Set 5 | thinadhoo
# Processing Record 44 of Set 5 | coahuayana
# Processing Record 45 of Set 5 | maningrida
# Processing Record 46 of Set 5 | nelson bay
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | nantucket
# Processing Record 49 of Set 5 | saint anthony
# Processing Record 50 of Set 5 | port blair
# Processing Record 1 of Set 6 | abu samrah
# Processing Record 2 of Set 6 | khatanga
# Processing Record 3 of Set 6 | castro
# Processing Record 4 of Set 6 | alugan
# Processing Record 5 of Set 6 | merauke
# Processing Record 6 of Set 6 | searcy
# Processing Record 7 of Set 6 | northam
# Processing Record 8 of Set 6 | qaanaaq
# Processing Record 9 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | camana
# Processing Record 12 of Set 6 | zhezkazgan
# Processing Record 13 of Set 6 | loreto
# Processing Record 14 of Set 6 | killybegs
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 | inuvik
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | lasa
# Processing Record 21 of Set 6 | tura
# Processing Record 22 of Set 6 | salym
# Processing Record 23 of Set 6 | embu
# Processing Record 24 of Set 6 | sibolga
# Processing Record 25 of Set 6 | nouakchott
# Processing Record 26 of Set 6 | mareeba
# Processing Record 27 of Set 6 | sao felix do xingu
# Processing Record 28 of Set 6 | babu
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | yaan
# Processing Record 31 of Set 6 | mangai
# Processing Record 32 of Set 6 | san andres
# Processing Record 33 of Set 6 | villazon
# Processing Record 34 of Set 6 | itapirapua
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | soe
# Processing Record 37 of Set 6 | kununurra
# Processing Record 38 of Set 6 | vanavara
# Processing Record 39 of Set 6 | conde
# Processing Record 40 of Set 6 | povenets
# Processing Record 41 of Set 6 | rovaniemi
# Processing Record 42 of Set 6 | lethem
# Processing Record 43 of Set 6 | awjilah
# Processing Record 44 of Set 6 | acari
# Processing Record 45 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 6 | lakes entrance
# Processing Record 47 of Set 6 | champasak
# Processing Record 48 of Set 6 | acapulco
# Processing Record 49 of Set 6 | sao joao de pirabas
# Processing Record 50 of Set 6 | dhidhdhoo
# Processing Record 1 of Set 7 | amberley
# Processing Record 2 of Set 7 | oranjemund
# Processing Record 3 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 7 | maarianhamina
# Processing Record 5 of Set 7 | kenai
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | longyearbyen
# Processing Record 8 of Set 7 | roald
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | ambon
# Processing Record 11 of Set 7 | taltal
# Processing Record 12 of Set 7 | santo angelo
# Processing Record 13 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | birao
# Processing Record 16 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 7 | vila franca do campo
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | kaohsiung
# Processing Record 20 of Set 7 | nara
# Processing Record 21 of Set 7 | izumo
# Processing Record 22 of Set 7 | carauari
# Processing Record 23 of Set 7 | miami
# Processing Record 24 of Set 7 | comodoro rivadavia
# Processing Record 25 of Set 7 | altamira
# Processing Record 26 of Set 7 | viransehir
# Processing Record 27 of Set 7 | pula
# Processing Record 28 of Set 7 | kaliua
# Processing Record 29 of Set 7 | nuuk
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | ust-omchug
# Processing Record 32 of Set 7 | severobaykalsk
# Processing Record 33 of Set 7 | shkoder
# Processing Record 34 of Set 7 | aklavik
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | etchoropo
# Processing Record 37 of Set 7 | charters towers
# Processing Record 38 of Set 7 | ginda
# Processing Record 39 of Set 7 | tautira
# Processing Record 40 of Set 7 | mus
# Processing Record 41 of Set 7 | benjamin hill
# Processing Record 42 of Set 7 | kupino
# Processing Record 43 of Set 7 | shangrao
# Processing Record 44 of Set 7 | morant bay
# Processing Record 45 of Set 7 | plettenberg bay
# Processing Record 46 of Set 7 | dharchula
# Processing Record 47 of Set 7 | rupert
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | synya
# Processing Record 1 of Set 8 | grand gaube
# Processing Record 2 of Set 8 | calama
# Processing Record 3 of Set 8 | seoul
# Processing Record 4 of Set 8 | poum
# Processing Record 5 of Set 8 | iralaya
# Processing Record 6 of Set 8 | kedrovyy
# Processing Record 7 of Set 8 | tyrma
# Processing Record 8 of Set 8 | zhangye
# Processing Record 9 of Set 8 | maniitsoq
# Processing Record 10 of Set 8 | malartic
# Processing Record 11 of Set 8 | ilhabela
# Processing Record 12 of Set 8 | harper
# Processing Record 13 of Set 8 | labuhan
# Processing Record 14 of Set 8 | bethanien
# Processing Record 15 of Set 8 | matay
# Processing Record 16 of Set 8 | sulangan
# Processing Record 17 of Set 8 | buraydah
# Processing Record 18 of Set 8 | hofn
# Processing Record 19 of Set 8 | cidreira
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | manzanillo
# Processing Record 22 of Set 8 | raudeberg
# Processing Record 23 of Set 8 | ust-kuyga
# Processing Record 24 of Set 8 | maple creek
# Processing Record 25 of Set 8 | sibu
# Processing Record 26 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 8 | salalah
# Processing Record 28 of Set 8 | eyl
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | berbera
# Processing Record 31 of Set 8 | zaplyusye
# City not found. Skipping...
# Processing Record 32 of Set 8 | mamallapuram
# Processing Record 33 of Set 8 | komsomolskiy
# Processing Record 34 of Set 8 | lata
# Processing Record 35 of Set 8 | ndjole
# Processing Record 36 of Set 8 | kamaishi
# Processing Record 37 of Set 8 | qianan
# Processing Record 38 of Set 8 | sangar
# Processing Record 39 of Set 8 | leshukonskoye
# Processing Record 40 of Set 8 | san carlos de bariloche
# Processing Record 41 of Set 8 | chimbote
# Processing Record 42 of Set 8 | bilibino
# Processing Record 43 of Set 8 | bahia blanca
# Processing Record 44 of Set 8 | vestmannaeyjar
# Processing Record 45 of Set 8 | olinda
# Processing Record 46 of Set 8 | kargil
# Processing Record 47 of Set 8 | adrar
# Processing Record 48 of Set 8 | skelleftea
# Processing Record 49 of Set 8 | saint-georges
# Processing Record 50 of Set 8 | cardenas
# Processing Record 1 of Set 9 | nishihara
# Processing Record 2 of Set 9 | konevo
# Processing Record 3 of Set 9 | bela
# Processing Record 4 of Set 9 | kisanga
# Processing Record 5 of Set 9 | monster
# Processing Record 6 of Set 9 | zhigansk
# Processing Record 7 of Set 9 | port macquarie
# Processing Record 8 of Set 9 | niigata
# Processing Record 9 of Set 9 | talnakh
# Processing Record 10 of Set 9 | alpena
# Processing Record 11 of Set 9 | general pico
# Processing Record 12 of Set 9 | bukama
# Processing Record 13 of Set 9 | turan
# Processing Record 14 of Set 9 | oktyabrskiy
# Processing Record 15 of Set 9 | clarksville
# Processing Record 16 of Set 9 | anloga
# Processing Record 17 of Set 9 | bara
# Processing Record 18 of Set 9 | hobyo
# Processing Record 19 of Set 9 | magadi
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | tsabong
# Processing Record 22 of Set 9 | utmanzai
# Processing Record 23 of Set 9 | jutai
# Processing Record 24 of Set 9 | amapa
# Processing Record 25 of Set 9 | san quintin
# Processing Record 26 of Set 9 | broken hill
# Processing Record 27 of Set 9 | salta
# Processing Record 28 of Set 9 | sfantu gheorghe
# Processing Record 29 of Set 9 | tabuk
# Processing Record 30 of Set 9 | maldonado
# Processing Record 31 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 32 of Set 9 | yarim
# Processing Record 33 of Set 9 | zehdenick
# Processing Record 34 of Set 9 | angoram
# Processing Record 35 of Set 9 | porto novo
# Processing Record 36 of Set 9 | rodrigues alves
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | moyale
# Processing Record 39 of Set 9 | rio do sul
# Processing Record 40 of Set 9 | necochea
# Processing Record 41 of Set 9 | beaufort
# Processing Record 42 of Set 9 | rawson
# Processing Record 43 of Set 9 | marienburg
# Processing Record 44 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 9 | skagen
# Processing Record 46 of Set 9 | moussoro
# Processing Record 47 of Set 9 | florianopolis
# Processing Record 48 of Set 9 | srednekolymsk
# Processing Record 49 of Set 9 | sabang
# Processing Record 50 of Set 9 | san isidro
# Processing Record 1 of Set 10 | douentza
# Processing Record 2 of Set 10 | quatre cocos
# Processing Record 3 of Set 10 | la rioja
# Processing Record 4 of Set 10 | vershino-shakhtaminskiy
# Processing Record 5 of Set 10 | yerbogachen
# Processing Record 6 of Set 10 | ixtapa
# Processing Record 7 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 10 | beloha
# Processing Record 9 of Set 10 | abilene
# Processing Record 10 of Set 10 | okhotsk
# Processing Record 11 of Set 10 | hangu
# Processing Record 12 of Set 10 | laredo
# Processing Record 13 of Set 10 | mezhdurechenskiy
# Processing Record 14 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 10 | tilichiki
# Processing Record 16 of Set 10 | burica
# City not found. Skipping...
# Processing Record 17 of Set 10 | karpogory
# Processing Record 18 of Set 10 | balakhta
# Processing Record 19 of Set 10 | wichita falls
# Processing Record 20 of Set 10 | onguday
# Processing Record 21 of Set 10 | ternate
# Processing Record 22 of Set 10 | wagar
# Processing Record 23 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | mackay
# Processing Record 26 of Set 10 | kholm-zhirkovskiy
# Processing Record 27 of Set 10 | waseca
# Processing Record 28 of Set 10 | baykit
# Processing Record 29 of Set 10 | nalut
# Processing Record 30 of Set 10 | terme
# Processing Record 31 of Set 10 | sao joao da barra
# Processing Record 32 of Set 10 | umm lajj
# Processing Record 33 of Set 10 | maues
# Processing Record 34 of Set 10 | kalmunai
# Processing Record 35 of Set 10 | whitehorse
# Processing Record 36 of Set 10 | umm kaddadah
# Processing Record 37 of Set 10 | qui nhon
# Processing Record 38 of Set 10 | kalakamati
# Processing Record 39 of Set 10 | plouzane
# Processing Record 40 of Set 10 | hay river
# Processing Record 41 of Set 10 | pomabamba
# Processing Record 42 of Set 10 | muzaffarabad
# Processing Record 43 of Set 10 | batangafo
# Processing Record 44 of Set 10 | shahpur
# Processing Record 45 of Set 10 | lavrentiya
# Processing Record 46 of Set 10 | teguise
# Processing Record 47 of Set 10 | pevek
# Processing Record 48 of Set 10 | jalali
# Processing Record 49 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 10 | landang
# City not found. Skipping...
# Processing Record 1 of Set 11 | usinsk
# Processing Record 2 of Set 11 | aquin
# Processing Record 3 of Set 11 | constantine
# Processing Record 4 of Set 11 | ust-nera
# Processing Record 5 of Set 11 | kiunga
# Processing Record 6 of Set 11 | tramore
# Processing Record 7 of Set 11 | cedar city
# Processing Record 8 of Set 11 | thomaston
# Processing Record 9 of Set 11 | dergachi
# Processing Record 10 of Set 11 | smolensk
# Processing Record 11 of Set 11 | russell
# Processing Record 12 of Set 11 | raga
# Processing Record 13 of Set 11 | gornopravdinsk
# Processing Record 14 of Set 11 | okulovka
# Processing Record 15 of Set 11 | mwene-ditu
# Processing Record 16 of Set 11 | imbituba
# Processing Record 17 of Set 11 | boyabat
# Processing Record 18 of Set 11 | neuquen
# Processing Record 19 of Set 11 | harindanga
# Processing Record 20 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 22 of Set 11 | ustka
# Processing Record 23 of Set 11 | semey
# Processing Record 24 of Set 11 | leh
# Processing Record 25 of Set 11 | tabas
# Processing Record 26 of Set 11 | asau
# Processing Record 27 of Set 11 | bosaso
# Processing Record 28 of Set 11 | mangrol
# Processing Record 29 of Set 11 | dandong
# Processing Record 30 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 31 of Set 11 | mega
# Processing Record 32 of Set 11 | san ramon
# Processing Record 33 of Set 11 | marechal candido rondon
# Processing Record 34 of Set 11 | sukumo
# Processing Record 35 of Set 11 | carlos chagas
# Processing Record 36 of Set 11 | pacific grove
# Processing Record 37 of Set 11 | taozhuang
# Processing Record 38 of Set 11 | ampanihy
# Processing Record 39 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 11 | byron bay
# Processing Record 41 of Set 11 | nichinan
# Processing Record 42 of Set 11 | bambanglipuro
# Processing Record 43 of Set 11 | banda aceh
# Processing Record 44 of Set 11 | rio gallegos
# Processing Record 45 of Set 11 | irtyshskiy
# Processing Record 46 of Set 11 | amur
# Processing Record 47 of Set 11 | basco
# Processing Record 48 of Set 11 | dzhebariki-khaya
# Processing Record 49 of Set 11 | narrabri
# Processing Record 50 of Set 11 | kali
# Processing Record 1 of Set 12 | sangin
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | yeniseysk
# Processing Record 4 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 12 | ailigandi
# Processing Record 6 of Set 12 | kamogawa
# Processing Record 7 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 12 | soyo
# Processing Record 9 of Set 12 | wanlaweyn
# Processing Record 10 of Set 12 | maryville
# Processing Record 11 of Set 12 | korogwe
# City not found. Skipping...
# Processing Record 12 of Set 12 | sao filipe
# Processing Record 13 of Set 12 | wanning
# Processing Record 14 of Set 12 | north platte
# Processing Record 15 of Set 12 | paita
# Processing Record 16 of Set 12 | suez
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | wewak
# Processing Record 19 of Set 12 | ambunti
# Processing Record 20 of Set 12 | alice springs
# Processing Record 21 of Set 12 | chulumani
# Processing Record 22 of Set 12 | coquimbo
# Processing Record 23 of Set 12 | tahta
# Processing Record 24 of Set 12 | flinders
# Processing Record 25 of Set 12 | puerto carreno
# Processing Record 26 of Set 12 | san jose de guanipa
# Processing Record 27 of Set 12 | bay roberts
# Processing Record 28 of Set 12 | nizhniy odes
# Processing Record 29 of Set 12 | sambava
# Processing Record 30 of Set 12 | namibe
# Processing Record 31 of Set 12 | humberto de campos
# Processing Record 32 of Set 12 | sumbe
# Processing Record 33 of Set 12 | aldan
# Processing Record 34 of Set 12 | caramay
# Processing Record 35 of Set 12 | warwick
# Processing Record 36 of Set 12 | kushiro
# Processing Record 37 of Set 12 | zhangjiakou
# Processing Record 38 of Set 12 | yangjiang
# Processing Record 39 of Set 12 | eureka
# Processing Record 40 of Set 12 | atagay
# Processing Record 41 of Set 12 | inhambane
# Processing Record 42 of Set 12 | toora-khem
# Processing Record 43 of Set 12 | mier
# Processing Record 44 of Set 12 | san juan de los morros
# Processing Record 45 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 12 | goderich
# Processing Record 47 of Set 12 | sandakan
# Processing Record 48 of Set 12 | ajdabiya
# Processing Record 49 of Set 12 | baker city
# Processing Record 50 of Set 12 | la primavera
# Processing Record 1 of Set 13 | xinglongshan
# Processing Record 2 of Set 13 | severo-yeniseyskiy
# Processing Record 3 of Set 13 | beira
# Processing Record 4 of Set 13 | kitimat
# Processing Record 5 of Set 13 | burnie
# Processing Record 6 of Set 13 | xianshuigu
# Processing Record 7 of Set 13 | nikolayevka
# Processing Record 8 of Set 13 | dehui
# Processing Record 9 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 13 | darhan
# Processing Record 11 of Set 13 | labelle
# Processing Record 12 of Set 13 | kemijarvi
# Processing Record 13 of Set 13 | nyagan
# Processing Record 14 of Set 13 | nevel
# Processing Record 15 of Set 13 | vila velha
# Processing Record 16 of Set 13 | katsuura
# Processing Record 17 of Set 13 | novomyrhorod
# Processing Record 18 of Set 13 | khilok
# Processing Record 19 of Set 13 | fuerte olimpo
# Processing Record 20 of Set 13 | abha
# Processing Record 21 of Set 13 | cockburn town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
city_weather
# Out:
# {'coord': {'lon': -71.14, 'lat': 21.46},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 78.6,
#   'feels_like': 79.09,
#   'temp_min': 78.6,
#   'temp_max': 78.6,
#   'pressure': 1018,
#   'humidity': 81,
#   'sea_level': 1018,
#   'grnd_level': 1017},
#  'wind': {'speed': 14.81, 'deg': 91},
#  'clouds': {'all': 42},
#  'dt': 1587258834,
#  'sys': {'country': 'TC', 'sunrise': 1587205338, 'sunset': 1587251090},
#  'timezone': -14400,
#  'id': 3576994,
#  'name': 'Cockburn Town',
#  'cod': 200}

# %%
#convert the array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Ushuaia -54.80  -68.30     48.20        57          40       10.29
# 1     Punta Arenas -53.15  -70.92     46.40        65          40       19.46
# 2       Bredasdorp -34.53   20.04     46.40        93          68        3.36
# 3          Mataura -46.19  168.86     55.99        65          67        8.99
# 4            Vardo  70.37   31.11     36.88        81          98       18.16
# ..             ...    ...     ...       ...       ...         ...         ...
# 565   Novomyrhorod  48.78   31.64     42.44        58          90        0.98
# 566         Khilok  51.37  110.47     27.05        69          96        9.55
# 567  Fuerte Olimpo -21.04  -57.87     69.85        51           9        0.63
# 568           Abha  18.22   42.51     62.60        87          20        3.58
# 569  Cockburn Town  21.46  -71.14     78.60        81          42       14.81
#
#     Country Current description  Rain (last 3 hrs)  Snow (last 3 hrs)  \
# 0        AR    scattered clouds                  0                  0
# 1        CL    scattered clouds                  0                  0
# 2        ZA       broken clouds                  0                  0
# 3        NZ       broken clouds                  0                  0
# 4        NO     overcast clouds                  0                  0
# ..      ...                 ...                ...                ...
# 565      UA     overcast clouds                  0                  0
# 566      RU     overcast clouds                  0                  0
# 567      PY           clear sky                  0                  0
# 568      SA          few clouds                  0                  0
# 569      TC    scattered clouds                  0                  0
#
#                     Date
# 0    2020-04-19 01:11:30
# 1    2020-04-19 01:08:30
# 2    2020-04-19 01:09:26
# 3    2020-04-19 01:11:32
# 4    2020-04-19 01:09:20
# ..                   ...
# 565  2020-04-19 01:17:14
# 566  2020-04-19 01:17:18
# 567  2020-04-19 01:17:18
# 568  2020-04-19 01:17:19
# 569  2020-04-19 01:13:54
#
# [570 rows x 12 columns]

# %%
#,#"Rain (last 3hrs)",#"Snow (last 3hrs)"
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current description","Rain (last 3 hrs)","Snow (last 3 hrs)"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0          Ushuaia      AR  2020-04-19 01:11:30 -54.80  -68.30     48.20
# 1     Punta Arenas      CL  2020-04-19 01:08:30 -53.15  -70.92     46.40
# 2       Bredasdorp      ZA  2020-04-19 01:09:26 -34.53   20.04     46.40
# 3          Mataura      NZ  2020-04-19 01:11:32 -46.19  168.86     55.99
# 4            Vardo      NO  2020-04-19 01:09:20  70.37   31.11     36.88
# ..             ...     ...                  ...    ...     ...       ...
# 565   Novomyrhorod      UA  2020-04-19 01:17:14  48.78   31.64     42.44
# 566         Khilok      RU  2020-04-19 01:17:18  51.37  110.47     27.05
# 567  Fuerte Olimpo      PY  2020-04-19 01:17:18 -21.04  -57.87     69.85
# 568           Abha      SA  2020-04-19 01:17:19  18.22   42.51     62.60
# 569  Cockburn Town      TC  2020-04-19 01:13:54  21.46  -71.14     78.60
#
#      Humidity  Cloudiness  Wind Speed Current description  Rain (last 3 hrs)  \
# 0          57          40       10.29    scattered clouds                  0
# 1          65          40       19.46    scattered clouds                  0
# 2          93          68        3.36       broken clouds                  0
# 3          65          67        8.99       broken clouds                  0
# 4          81          98       18.16     overcast clouds                  0
# ..        ...         ...         ...                 ...                ...
# 565        58          90        0.98     overcast clouds                  0
# 566        69          96        9.55     overcast clouds                  0
# 567        51           9        0.63           clear sky                  0
# 568        87          20        3.58          few clouds                  0
# 569        81          42       14.81    scattered clouds                  0
#
#      Snow (last 3 hrs)
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 565                  0
# 566                  0
# 567                  0
# 568                  0
# 569                  0
#
# [570 rows x 12 columns]

# %%
#create the output file (CSV)
output_data_file = "weather_data/WeatherPy_challenge.csv"
#export the challenge weather data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
